# %%
import pandas as pd

# %%
baseline_result = 'model/results/baseline20_results_20241028-072506.csv'
res=pd.read_csv(baseline_result)
print(len(res))
res.mean()
# Out:
# 938
# rougeLsum      21.749067
# length       3439.135394
# str_em         49.358564
# ovscore        21.917980
# dtype: float64
