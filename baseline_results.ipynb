# %%
import pandas as pd

# %%
baseline_result = 'baseline_results_20241027-053837.csv'
res=pd.read_csv(baseline_result)[:300]
print(len(res))
res.mean()
# Out:
# 300
# rougeLsum    32.342845
# length       80.843333
# str_em       36.338889
# ovscore      27.932262
# dtype: float64
