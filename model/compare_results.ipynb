# %%
import pandas as pd
import os

sf = pd.read_csv('results/self-refine-11-25_results.csv')
sf=sf[sf['length']<1000][:90]
print(len(sf))
print(sf.mean())
# Out:
# 90
# rougeLsum       32.525089
# length         157.577778
# str_em          47.055556
# Disambig-F1     41.350847
# ovscore         32.409516
# dtype: float64

# %%
import math
sf = pd.read_csv('results/self-refine-11-27_results.csv')
sf=sf[sf['length']<1000][:90]
print(len(sf))
print(sf.mean())
r=sf.mean()['rougeLsum']
d=sf.mean()['Disambig-F1']
dr=math.sqrt(r*d)
print(dr)
# Out:
# 90
# rougeLsum       34.490120
# length         147.022222
# str_em          55.388889
# Disambig-F1     43.196564
# dtype: float64
# 38.598635419306405

# %%
import math
sf = pd.read_csv('results/self-refine-11-27-2_results.csv')
sf=sf[sf['length']<1000][:90]
print(len(sf))
print(sf.mean())
r=sf.mean()['rougeLsum']
d=sf.mean()['Disambig-F1']
dr=math.sqrt(r*d)
print(dr)
# Out:
# 90
# rougeLsum       36.477957
# length         115.433333
# str_em          55.259259
# Disambig-F1     47.782554
# ovscore         39.345683
# dtype: float64
# 41.749370773942786

# %%
base = pd.read_csv('results/baseline-11-25_results.csv')
base =base[base['length']<1000][:90]
print(len(base))
print(base.mean())
import math
r=base.mean()['rougeLsum']
d=base.mean()['Disambig-F1']
dr=math.sqrt(r*d)
print(dr)
# Out:
# 90
# rougeLsum      34.403708
# length         36.277778
# str_em         47.685185
# Disambig-F1    44.589676
# ovscore        35.961270
# dtype: float64
# 39.166952810580945

# %%
sf = pd.read_csv('results/self-refine-10-29_results.csv')
sf=sf[sf['length']<1000][:90]
print(len(sf))
print(sf.mean())
# Out:
# 90
# rougeLsum     32.520156
# length       151.633333
# str_em        50.629630
# ovscore       36.779201
# dtype: float64

# %%
base = pd.read_csv('results/baseline_results_20241027-053837.csv')
base =base[base['length']<1000][:90]
print(len(base))
print(base.mean())
# Out:
# 90
# rougeLsum    30.938210
# length       43.777778
# str_em       33.111111
# ovscore      25.804131
# dtype: float64
