# %%
import pandas as pd
import os

res_df = pd.DataFrame(columns=['model','timestamp','rougeLsum','length','str_em','ovscore'])

for file in os.listdir('./results'):
    if file.endswith('.csv'):
        mean = pd.read_csv(f'./results/{file}')
        mean=mean[mean['length']<1000][:97].mean().to_list()
        file_name  = file.strip('.csv').split('_')
        model_name = file_name[0] if len(file_name) >=1 else 'unk'
        timestamp = pd.to_datetime(file_name[2] if len(file_name) >= 3 else None, format="%Y%m%d-%H%M%S")
        res_df.loc[len(res_df)] = [file_name, timestamp] + mean

res_df.sort_values('timestamp', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 13
#      11         model_name = file_name[0] if len(file_name) >=1 else 'unk'
#      12         timestamp = pd.to_datetime(file_name[2] if len(file_name) >= 3 else None, format="%Y%m%d-%H%M%S")
# ---> 13         res_df.loc[len(res_df)] = [file_name, timestamp] + mean
#      15 res_df.sort_values('timestamp', ascending=False)
#
# File ~/anaconda3/envs/sf_rag_djk/lib/python3.10/site-packages/pandas/core/indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/anaconda3/envs/sf_rag_djk/lib/python3.10/site-packages/pandas/core/indexing.py:1932, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
# ...

# %%
import pandas as pd
import os

sf = pd.read_csv('results/self-refine-11-25_results.csv')
sf=sf[sf['length']<1000][:90]
print(len(sf))
print(sf.mean())
# Out:
# 90
# rougeLsum       32.525089
# length         157.577778
# str_em          47.055556
# Disambig-F1     41.350847
# ovscore         32.409516
# dtype: float64

# %%
base = pd.read_csv('results/baseline-11-25_results.csv')
base =base[base['length']<1000][:90]
print(len(base))
print(base.mean())
# Out:
# 90
# rougeLsum      31.651130
# length         38.822222
# str_em         36.666667
# Disambig-F1    37.386414
# ovscore        29.604084
# dtype: float64

# %%
base = pd.read_csv('results/baseline_results_20241027-053837.csv')
base =base[base['length']<1000][:120]
print(len(base))
print(base.mean())
# Out:
# 120
# rougeLsum    31.900460
# length       45.800000
# str_em       34.208333
# ovscore      26.921278
# dtype: float64
