# %%
import pandas as pd
import os

sf = pd.read_csv('results/self-refine-11-25_results.csv')
sf=sf[sf['length']<1000][:90]
print(len(sf))
print(sf.mean())
# Out:
# 90
# rougeLsum       32.525089
# length         157.577778
# str_em          47.055556
# Disambig-F1     41.350847
# ovscore         32.409516
# dtype: float64

# %%
import math
sf = pd.read_csv('results/self-refine-11-27_results.csv')
sf=sf[sf['length']<1000][:90]
print(len(sf))
print(sf.mean())
r=sf.mean()['rougeLsum']
d=sf.mean()['Disambig-F1']
dr=math.sqrt(r*d)
print(dr)
# Out:
# 90
# rougeLsum       34.490120
# length         147.022222
# str_em          55.388889
# Disambig-F1     43.196564
# dtype: float64
# 38.598635419306405

# %%
import math
sf = pd.read_csv('results/self-refine-11-27-2_results.csv')
sf=sf[sf['length']<1000][:100]
print(len(sf))
print(sf.mean())
r=sf.mean()['rougeLsum']
d=sf.mean()['Disambig-F1']
dr=math.sqrt(r*d)
print(dr)
# Out:
# 100
# rougeLsum       36.459512
# length         120.060000
# str_em          55.383333
# Disambig-F1     46.892394
# ovscore         38.757972
# dtype: float64
# 41.34820206876455

# %%
base = pd.read_csv('results/baseline-11-25_results.csv')
base =base[base['length']<1000][:100]
print(len(base))
print(base.mean())
import math
r=base.mean()['rougeLsum']
d=base.mean()['Disambig-F1']
dr=math.sqrt(r*d)
print(dr)
# Out:
# 100
# rougeLsum      33.692212
# length         38.380000
# str_em         48.233333
# Disambig-F1    44.380708
# ovscore        35.399471
# dtype: float64
# 38.66890510574455
