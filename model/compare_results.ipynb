# %%
import pandas as pd
import os

res_df = pd.DataFrame(columns=['model','timestamp','rougeLsum','length','str_em','ovscore'])

for file in os.listdir('./results'):
    if file.endswith('.csv'):
        mean = pd.read_csv(f'./results/{file}')
        mean=mean[mean['length']<1000][:97].mean().to_list()
        file_name  = file.strip('.csv').split('_')
        model_name = file_name[0] if len(file_name) >=1 else 'unk'
        timestamp = pd.to_datetime(file_name[2] if len(file_name) >= 3 else None, format="%Y%m%d-%H%M%S")
        res_df.loc[len(res_df)] = [file_name, timestamp] + mean

res_df.sort_values('timestamp', ascending=False)
# Out:
# /tmp/ipykernel_2920553/277417287.py:13: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   res_df.loc[len(res_df)] = [file_name, timestamp] + mean
# /tmp/ipykernel_2920553/277417287.py:13: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   res_df.loc[len(res_df)] = [file_name, timestamp] + mean
# /tmp/ipykernel_2920553/277417287.py:13: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   res_df.loc[len(res_df)] = [file_name, timestamp] + mean
# /tmp/ipykernel_2920553/277417287.py:13: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   res_df.loc[len(res_df)] = [file_name, timestamp] + mean
#                                     model           timestamp  rougeLsum  \
# 5  [baseline20, results, 20241028-072506] 2024-10-28 07:25:06  30.270575
# 0    [baseline, results, 20241027-053837] 2024-10-27 05:38:37  31.064264
# 1                [elf-refine-120, result]                 NaT  33.914448
# 2              [elf-refine-10-30, result]                 NaT        NaN
# 3              [elf-refine-10-29, result]                 NaT  32.238922
# 4             [elf-refine-120new, result]                 NaT  33.562414
#
#        length     str_em    ovscore
# 5   45.030928  36.907216  26.860482
# 0   43.340206  33.384880  25.954441
# 1   78.237113  38.487973  30.019677
# 2         NaN        NaN        NaN
# 3  155.917526  51.443299  36.876440
# 4  112.731959  44.312715  33.319938
