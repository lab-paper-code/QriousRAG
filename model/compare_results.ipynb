# %%
import pandas as pd
import os

res_df = pd.DataFrame(columns=['model','timestamp','rougeLsum','length','str_em','ovscore'])

for file in os.listdir('./results'):
    if file.endswith('.csv'):
        mean = pd.read_csv(f'./results/{file}').mean().to_list()
        file_name  = file.strip('.csv').split('_')
        model_name = file_name[0] if len(file_name) >=1 else 'unk'
        timestamp = pd.to_datetime(file_name[2] if len(file_name) >= 3 else None, format="%Y%m%d-%H%M%S")
        res_df.loc[len(res_df)] = [file_name, timestamp] + mean

res_df.sort_values('timestamp', ascending=False)
# Out:
# /tmp/ipykernel_126757/1293031705.py:12: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   res_df.loc[len(res_df)] = [file_name, timestamp] + mean
# /tmp/ipykernel_126757/1293031705.py:12: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   res_df.loc[len(res_df)] = [file_name, timestamp] + mean
#                                     model           timestamp  rougeLsum  \
# 4  [baseline20, results, 20241028-072506] 2024-10-28 07:25:06  21.749067
# 0    [baseline, results, 20241027-053837] 2024-10-27 05:38:37  32.859843
# 3    [baseline, results, 20241027-021908] 2024-10-27 02:19:08  32.442865
# 1                    [elf-refine, result]                 NaT  34.638232
# 2                      [baseline, result]                 NaT  31.055942
#
#         length     str_em    ovscore
# 4  3439.135394  49.358564  21.917980
# 0    73.800640  38.521677  29.769232
# 3    30.950000  31.666667  25.803667
# 1    78.500000  33.333333  24.124895
# 2    52.000000  33.333333  27.048043
