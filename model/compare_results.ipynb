# %%
import pandas as pd
import os

res_df = pd.DataFrame(columns=['model','timestamp','rougeLsum','length','str_em','ovscore'])

for file in os.listdir('./results'):
    if file.endswith('.csv'):
        mean = pd.read_csv(f'./results/{file}')
        mean=mean[mean['length']<1000].mean().to_list()
        file_name  = file.strip('.csv').split('_')
        model_name = file_name[0] if len(file_name) >=1 else 'unk'
        timestamp = pd.to_datetime(file_name[2] if len(file_name) >= 3 else None, format="%Y%m%d-%H%M%S")
        res_df.loc[len(res_df)] = [file_name, timestamp] + mean

res_df.sort_values('timestamp', ascending=False)
# Out:
# /tmp/ipykernel_132698/3456942954.py:13: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   res_df.loc[len(res_df)] = [file_name, timestamp] + mean
# /tmp/ipykernel_132698/3456942954.py:13: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   res_df.loc[len(res_df)] = [file_name, timestamp] + mean
#                                     model           timestamp  rougeLsum  \
# 2  [baseline20, results, 20241028-072506] 2024-10-28 07:25:06  31.828935
# 0    [baseline, results, 20241027-053837] 2024-10-27 05:38:37  33.024798
# 1                    [elf-refine, result]                 NaT  32.179459
# 3              [elf-refine-prior, result]                 NaT  30.599844
#
#       length     str_em    ovscore
# 2  41.988836  36.940457  28.059322
# 0  41.847803  38.390497  29.870102
# 1  74.738095  37.182540  27.829170
# 3  45.825000  36.625000  27.909348
