# %%
# 기본 라그 예전 데이터 문서 10개 검색 함수는 기본함수 toal_answer
# first_retrival    0.675
# first_title_retrival    0.9175
import pandas as pd
import math
sf = pd.read_csv('results/basicRAG-total-seed24-len200_results.csv')
sf=sf[sf['length']<1000][:200]
print(len(sf))
print(sf.mean())
r=sf.mean()['rougeLsum']
d=sf.mean()['Disambig-F1']
dr=math.sqrt(r*d)
print(dr)
# Out:
# 197
# rougeLsum      39.679668
# length         97.091371
# str_em         57.275804
# Disambig-F1    49.866315
# dtype: float64
# 44.48234273193129

# %%
import pandas as pd
import math
sf = pd.read_csv('results/prompt-AF_results.csv')
sf=sf[sf['length']<1000][:197]
print(len(sf))
print(sf.mean())
r=sf.mean()['rougeLsum']
d=sf.mean()['Disambig-F1']
dr=math.sqrt(r*d)
print(dr)
# Out:
# 197
# Unnamed: 0     98.000000
# rougeLsum      37.429627
# length         93.142132
# str_em         54.382403
# Disambig-F1    46.311030
# dtype: float64
# 41.63417559263471
