# %%
import json
import os
import random

SEED = 42
random.seed(42)

# %%
# load data
data = []
with open('/raid/deallab/SF_RAG_Data/N_Q/nq-train.jsonl', 'r') as f:
    for i, line in enumerate(list(f)):
        try:
            data.append(json.loads(line))
        except:
            print(f'Could not load line {i}')
            continue
    

len(data)
# Out:
# 307373

# %%
# sample from whole data
sample = random.sample(data, 10000)

# %%
sample[0]
# Out:
# {'document_text': 'Fear the Walking Dead ( season 4 ) - wikipedia <H1> Fear the Walking Dead ( season 4 ) </H1> <Table> <Tr> <Th_colspan="2"> Fear the Walking Dead ( season 4 ) </Th> </Tr> <Tr> <Td_colspan="2"> Promotional poster </Td> </Tr> <Tr> <Th> Starring </Th> <Td> <Ul> <Li> Kim Dickens </Li> <Li> Frank Dillane </Li> <Li> Alycia Debnam - Carey </Li> <Li> Maggie Grace </Li> <Li> Colman Domingo </Li> <Li> Danay García </Li> <Li> Garret Dillahunt </Li> <Li> Lennie James </Li> <Li> Jenna Elfman </Li> </Ul> </Td> </Tr> <Tr> <Th> Country of origin </Th> <Td> United States </Td> </Tr> <Tr> <Th> No. of episodes </Th> <Td> 16 </Td> </Tr> <Tr> <Th_colspan="2"> Release </Th> </Tr> <Tr> <Th> Original network </Th> <Td> AMC </Td> </Tr> <Tr> <Th> Original release </Th> <Td> April 15 ( 2018 - 04 - 15 ) -- September 30 , 2018 ( 2018 - 09 - 30 ) </Td> </Tr> <Tr> <Th_colspan="2"> Season chronology </Th> </Tr> <Tr> <Td_colspan="2"> ← Previous Season 3 </Td> </Tr> <Tr> <Td_colspan="2"> List of Fear the Walking Dead episodes </Td> </Tr> </Table> <P> The fourth season of Fear the Walking Dead , an American horror - drama television series on AMC , premiered on April 15 , 2018 , and comprises 16 episodes split into two eight - episode parts . The second half of the season premiered on August 12 , 2018 , and concluded on September 30 , 2018 . It is a companion series to The Walking Dead , and the season premiere contained the first crossover between the two series . The season features new showrunners Andrew Chambliss and Ian B. Goldberg , and the series also moved to a new filming location , Austin , Texas . </P> <P> The season follows a dysfunctional family composed of Madison Clark ( Kim Dickens ) , her daughter Alicia ( Alycia Debnam - Carey ) , her drug - addicted son Nick ( Frank Dillane ) and his lover Luciana Galvez ( Danay García ) , along with Victor Strand ( Colman Domingo ) during the zombie apocalypse . The group finds safe haven inside a baseball stadium , but are threatened by a group of antagonistic survivors known as the Vultures . It also features several new characters including The Walking Dead \'s Morgan Jones ( Lennie James ) , as well as characters played by Maggie Grace , Garret Dillahunt , and Jenna Elfman . </P> <H2> Contents </H2> <Ul> <Li> 1 Cast <Ul> <Li> 1.1 Main cast </Li> <Li> 1.2 Supporting cast </Li> <Li> 1.3 Guest cast </Li> </Ul> </Li> <Li> 2 Episodes </Li> <Li> 3 Production and writing </Li> <Li> 4 Release </Li> <Li> 5 Reception <Ul> <Li> 5.1 Critical response </Li> <Li> 5.2 Ratings </Li> </Ul> </Li> <Li> 6 References </Li> <Li> 7 External links </Li> </Ul> <H2> Cast ( edit ) </H2> Kim Dickens ( Madison Clark ) , Frank Dillane ( Nick Clark ) , and Alycia Debnam - Carey ( Alicia Clark ) Maggie Grace ( Althea ) , Colman Domingo ( Victor Strand ) , and Danay García ( Luciana Galvez ) Garret Dillahunt ( John Dorie ) , Lennie James ( Morgan Jones ) , and Jenna Elfman ( June / Naomi / Laura ) <H3> Main cast ( edit ) </H3> <P> The fourth season features nine actors receiving main cast billing status , with five returning from the third season , while four new cast members are introduced . Lennie James ( who was a main cast member in The Walking Dead ) , moved to the main cast after his departure from The Walking Dead . Maggie Grace , Garret Dillahunt and Jenna Elfman were added to the main cast . This is the first season not to include Cliff Curtis , Mercedes Mason , Daniel Sharman , Sam Underwood , Dayton Callie , Rubén Blades and Lisandra Tena ( since their first appearances ) , who were all credited as main cast members in previous seasons . </P> <Ul> <Li> Kim Dickens as Madison Clark : An intelligent and domineering high school guidance counselor and the mother of Nick and Alicia . </Li> <Li> Frank Dillane as Nick Clark : A brave and selfless recovering heroin addict , Madison \'s son , and Alicia \'s brother . </Li> <Li> Alycia Debnam - Carey as Alicia Clark : The fiery yet compassionate daughter of Madison ,  ...
#  'long_answer_candidates': [{'start_token': 20,
#    'top_level': True,
#    'end_token': 176},
#   {'start_token': 21, 'top_level': False, 'end_token': 33},
#   {'start_token': 33, 'top_level': False, 'end_token': 39},
#   {'start_token': 39, 'top_level': False, 'end_token': 86},
#   {'start_token': 44, 'top_level': False, 'end_token': 84},
#   {'start_token': 53, 'top_level': False, 'end_token': 59},
#   {'start_token': 86, 'top_level': False, 'end_token': 97},
#   {'start_token': 97, 'top_level': False, 'end_token': 107},
#   {'start_token': 107, 'top_level': False, 'end_token': 112},
#   {'start_token': 112, 'top_level': False, 'end_token': 121},
#   {'start_token': 121, 'top_level': False, 'end_token': 150},
#   {'start_token': 150, 'top_level': False, 'end_token': 156},
#   {'start_token': 156, 'top_level': False, 'end_token': 164},
#   {'start_token': 164, 'top_level': False, 'end_token': 175},
#   {'start_token': 176, 'top_level': True, 'end_token': 287},
#   {'start_token': 287, 'top_level': True, 'end_token': 405},
#   {'start_token': 549, 'top_level': True, 'end_token': 669},
#   {'start_token': 669, 'top_level': True, 'end_token': 892},
#   {'start_token': 670, 'top_level': False, 'end_token': 694},
#   {'start_token': 694, 'top_level': False, 'end_token': 719},
#   {'start_token': 719, 'top_level': False, 'end_token': 743},
#   {'start_token': 743, 'top_level': False, 'end_token': 761},
#   {'start_token': 761, 'top_level': False, 'end_token': 787},
#   {'start_token': 787, 'top_level': False, 'end_token': 816},
#   {'start_token': 816, 'top_level': False, 'end_token': 834},
#   {'start_token': 834, 'top_level': False, 'end_token': 871},
#   {'start_token': 871, 'top_level': False, 'end_token': 891},
#   {'start_token': 899, 'top_level': True, 'end_token': 1092},
#   {'start_token': 900, 'top_level': False, 'end_token': 919},
#   {'start_token': 919, 'top_level': False, 'end_token': 937},
#   {'start_token': 937, 'top_level': False, 'end_token': 954},
#   {'start_token': 954, 'top_level': False, 'end_token': 976},
#   {'start_token': 976, 'top_level': False, 'end_token': 994},
#   {'start_token': 994, 'top_level': False, 'end_token': 1017},
#   {'start_token': 1017, 'top_level': False, 'end_token': 1033},
#   {'start_token': 1033, 'top_level': False, 'end_token': 1052},
#   {'start_token': 1052, 'top_level': False, 'end_token': 1069},
#   {'start_token': 1069, 'top_level': False, 'end_token': 1091},
#   {'start_token': 1099, 'top_level': True, 'end_token': 1192},
#   {'start_token': 1100, 'top_level': False, 'end_token': 1133},
#   {'start_token': 1133, 'top_level': False, 'end_token': 1152},
#   {'start_token': 1152, 'top_level': False, 'end_token': 1174},
#   {'start_token': 1174, 'top_level': False, 'end_token': 1191},
#   {'start_token': 1208, 'top_level': True, 'end_token': 5928},
#   {'start_token': 1209, 'top_level': False, 'end_token': 1244},
#   {'start_token': 1244, 'top_level': False, 'end_token': 1291},
#   {'start_token': 1291, 'top_level': False, 'end_token': 1456},
#   {'start_token': 1456, 'top_level': False, 'end_token': 1500},
#   {'start_token': 1500, 'top_level': False, 'end_token': 1748},
#   {'start_token': 1748, 'top_level': False, 'end_token': 1786},
#   {'start_token': 1786, 'top_level': False, 'end_token': 2008},
#   {'start_token': 2008, 'top_level': False, 'end_token': 2044},
#   {'start_token': 2044, 'top_level': False, 'end_token': 2301},
#   {'start_token': 2301, 'top_level': False, 'end_token': 2339},
#   {'start_token': 2339, 'top_level': False, 'end_token': 2592},
#   {'start_token': 2592, 'top_level': False, 'end_token': 2633},
#   {'start_token': 2633, 'top_level': False, 'end_token': 2867},
#   {'start_token': 2867, 'top_level': False, 'end_token': 2912},
#   {'start_token': 2912, 'top_level': False, 'end_token': 3148},
#   {'start_token': 3148, 'top_level': False, 'end_token': 3192},
#   {'start_token': 3192, 'top_level': False, 'end_token': 3434},
#   {'start_token': 3434, 'top_level': False, 'end_token': 3473},
#   {'start_token': 3473, 'top_level': False, 'end_token': 3714},
#   {'start_token': 3714, 'top_level': False, 'end_token': 3754},
#   {'start_token': 3754, 'top_level': False, 'end_token': 4023},
#   {'start_token': 4023, 'top_level': False, 'end_token': 4065},
#   {'start_token': 4065, 'top_level': False, 'end_token': 4348},
#   {'start_token': 4348, 'top_level': False, 'end_token': 4385},
#   {'start_token': 4385, 'top_level': False, 'end_token': 4674},
#   {'start_token': 4674, 'top_level': False, 'end_token': 4714},
#   {'start_token': 4714, 'top_level': False, 'end_token': 4986},
#   {'start_token': 4986, 'top_level': False, 'end_token': 5028},
#   {'start_token': 5028, 'top_level': False, 'end_token': 5248},
#   {'start_token': 5248, 'top_level': False, 'end_token': 5288},
#   {'start_token': 5288, 'top_level': False, 'end_token': 5577},
#   {'start_token': 5577, 'top_level': False, 'end_token': 5621},
#   {'start_token': 5621, 'top_level': False, 'end_token': 5927},
#   {'start_token': 5951, 'top_level': True, 'end_token': 6026},
#   {'start_token': 6026, 'top_level': True, 'end_token': 6083},
#   {'start_token': 6083, 'top_level': True, 'end_token': 6106},
#   {'start_token': 6106, 'top_level': True, 'end_token': 6172},
#   {'start_token': 6172, 'top_level': True, 'end_token': 6188},
#   {'start_token': 6188, 'top_level': True, 'end_token': 6295},
#   {'start_token': 6295, 'top_level': True, 'end_token': 6450},
#   {'start_token': 6450, 'top_level': True, 'end_token': 6497},
#   {'start_token': 6497, 'top_level': True, 'end_token': 6622},
#   {'start_token': 6628, 'top_level': True, 'end_token': 6720},
#   {'start_token': 6733, 'top_level': True, 'end_token': 6847},
#   {'start_token': 6847, 'top_level': True, 'end_token': 6955},
#   {'start_token': 6955, 'top_level': True, 'end_token': 6994},
#   {'start_token': 6969, 'top_level': False, 'end_token': 6993},
#   {'start_token': 6971, 'top_level': False, 'end_token': 6991},
#   {'start_token': 6972, 'top_level': False, 'end_token': 6990},
#   {'start_token': 7000, 'top_level': True, 'end_token': 7649},
#   {'start_token': 7001, 'top_level': False, 'end_token': 7058},
#   {'start_token': 7058, 'top_level': False, 'end_token': 7095},
#   {'start_token': 7095, 'top_level': False, 'end_token': 7132},
#   {'start_token': 7132, 'top_level': False, 'end_token': 7167},
#   {'start_token': 7167, 'top_level': False, 'end_token': 7208},
#   {'start_token': 7208, 'top_level': False, 'end_token': 7242},
#   {'start_token': 7242, 'top_level': False, 'end_token': 7286},
#   {'start_token': 7286, 'top_level': False, 'end_token': 7327},
#   {'start_token': 7327, 'top_level': False, 'end_token': 7364},
#   {'start_token': 7364, 'top_level': False, 'end_token': 7400},
#   {'start_token': 7400, 'top_level': False, 'end_token': 7436},
#   {'start_token': 7436, 'top_level': False, 'end_token': 7471},
#   {'start_token': 7471, 'top_level': False, 'end_token': 7505},
#   {'start_token': 7505, 'top_level': False, 'end_token': 7539},
#   {'start_token': 7539, 'top_level': False, 'end_token': 7574},
#   {'start_token': 7574, 'top_level': False, 'end_token': 7611},
#   {'start_token': 7611, 'top_level': False, 'end_token': 7648},
#   {'start_token': 7649, 'top_level': True, 'end_token': 7676},
#   {'start_token': 7650, 'top_level': False, 'end_token': 7675}],
#  'question_text': 'fear the walking dead season 4 ep list',
#  'annotations': [{'yes_no_answer': 'NONE',
#    'long_answer': {'start_token': 1208,
#     'candidate_index': 43,
#     'end_token': 5928},
#    'short_answers': [],
#    'annotation_id': 16028728729684661806}],
#  'document_url': 'https://en.wikipedia.org//w/index.php?title=Fear_the_Walking_Dead_(season_4)&amp;oldid=866430752',
#  'example_id': -2983727301620977186}

# %%
# create evidence files
files = {}
for s in sample:
    id = s['example_id']
    text = s['document_text'].split()
    chunks = [(chunk['start_token'],chunk['end_token']) for chunk in s['long_answer_candidates'] if chunk['top_level']==True]
    for start, end in chunks:
        print(start, end)
        files[f'{id}_{start}_{end}'] = ' '.join(text[start, end])
# Out:
# 20 176
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 9
#       7 for start, end in chunks:
#       8     print(start, end)
# ----> 9     files[f'{id}_{start}_{end}'] = ' '.join(text[start, end])
#
# TypeError: list indices must be integers or slices, not tuple
